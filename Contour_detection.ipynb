# %% [markdown]
# Contour detection

# %% [markdown]
# Image2

# %%
import cv2
import matplotlib.pyplot as plt 
import numpy as np

# %%
img = cv2.imread('roads_input1.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
# Aplly blurred 
blurred = cv2.GaussianBlur(gray, (5,5), 0)

# %%
# Aplly cany edge detection 
edges = cv2.Canny(blurred, 100, 200)

# %%
# Find Contours 
contours, hierarchy = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
# Draw contours to the original image 
contour_image = img.copy()
cv2.drawContours(contour_image, contours, -1, (0, 255, 0), 2)
# Out:
# array([[[216, 198, 181],
#         [216, 198, 181],
#         [216, 198, 181],
#         ...,
#         [206, 175, 144],
#         [206, 175, 144],
#         [205, 174, 143]],
#
#        [[216, 198, 181],
#         [216, 198, 181],
#         [216, 198, 181],
#         ...,
#         [204, 175, 144],
#         [206, 175, 144],
#         [205, 174, 143]],
#
#        [[217, 199, 182],
#         [217, 199, 182],
#         [216, 198, 181],
#         ...,
#         [204, 175, 144],
#         [206, 175, 144],
#         [205, 174, 143]],
#
#        ...,
#
#        [[ 24,  24,  24],
#         [ 25,  25,  25],
#         [ 25,  25,  25],
#         ...,
#         [ 75,  76,  72],
#         [ 78,  79,  75],
#         [ 72,  73,  69]],
#
#        [[ 30,  28,  28],
#         [ 31,  29,  29],
#         [ 31,  29,  29],
#         ...,
#         [ 70,  66,  65],
#         [ 68,  66,  66],
#         [ 69,  67,  67]],
#
#        [[ 30,  28,  28],
#         [ 31,  29,  29],
#         [ 31,  29,  29],
#         ...,
#         [ 71,  67,  66],
#         [ 69,  67,  67],
#         [ 70,  68,  68]]], dtype=uint8)

# %%
# visualization 
# Display results
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
plt.title("Original Image")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

plt.subplot(1, 3, 2)
plt.title("Edges")
plt.imshow(edges, cmap='gray')

plt.subplot(1, 3, 3)
plt.title("Contours")
plt.imshow(cv2.cvtColor(contour_image, cv2.COLOR_BGR2RGB))

plt.tight_layout()
plt.savefig('output1_result.png')
plt.show()

# %% [markdown]
# Image 2

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('roads_input2.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply Gaussian blur to reduce noise
blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# Apply Canny edge detection
edges = cv2.Canny(blurred, 100, 200)

# Find contours
contours, hierarchy = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Draw contours on the original image
contour_image = image.copy()
cv2.drawContours(contour_image, contours, -1, (0, 255, 0), 2)

# Display results
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
plt.title("Original Image")
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

plt.subplot(1, 3, 2)
plt.title("Edges")
plt.imshow(edges, cmap='gray')

plt.subplot(1, 3, 3)
plt.title("Contours")
plt.imshow(cv2.cvtColor(contour_image, cv2.COLOR_BGR2RGB))

plt.tight_layout()
plt.savefig('output2_result.png')
plt.show()

# %%
# Done
