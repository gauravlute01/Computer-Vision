# %% [markdown]
# Histogram and its Equalization

# %%
import cv2
import matplotlib.pyplot as plt 
import numpy as np

# %% [markdown]
# Image1

# %%
img = cv2.imread('solar_panle_2.jpg', 1)
#img = img.astype(np.uint8)  # Convert to uint8
plt.imshow(img)
print(img.shape)
# Out:
# (593, 294, 3)

# %%
#Converting image to LAB Color so CLAHE can be applied to the luminance channel
lab_img= cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
plt.imshow(lab_img)

# %%
#Splitting the LAB image to L, A and B channels, respectively
l, a, b = cv2.split(lab_img)

# %%
#Apply histogram equalization to the L channel
equ = cv2.equalizeHist(l)
plt.hist(equ.flat, bins=100, range=(0,255))
plt.show()

# %%
#Combine the Hist. equalized L-channel back with A and B channels
updated_lab_img1 = cv2.merge((equ,a,b))

# %%
#Convert LAB image back to color (RGB)
hist_eq_img = cv2.cvtColor(updated_lab_img1, cv2.COLOR_LAB2BGR)

# %%
#Apply CLAHE to L channel
clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
clahe_img = clahe.apply(l)
plt.hist(clahe_img.flat, bins=100, range=(0,255))
plt.show()

# %%
#Combine the CLAHE enhanced L-channel back with A and B channels
updated_lab_img2 = cv2.merge((clahe_img,a,b))

# %%
#Convert LAB image back to color (RGB)
CLAHE_img = cv2.cvtColor(updated_lab_img2, cv2.COLOR_LAB2BGR)

# %%
plt.figure(figsize=(12,10))
plt.subplot(3,3,1)
plt.title('Original Image')
plt.imshow(img)

plt.subplot(3,3,2)
plt.title('Hist_eq_image')
plt.imshow(hist_eq_img)

plt.subplot(3,3,3)
plt.title('CLAHE_image')
plt.imshow(CLAHE_img)

plt.subplot(3,3,4)
plt.title('Histogram equ')
plt.hist(equ.flat, bins=100, range=(0,255))

plt.subplot(3,3,5)
plt.title('updated_lab_img2')
plt.imshow(updated_lab_img1)

plt.subplot(3,3,6)
plt.title('updated_lab_img2')
plt.imshow(updated_lab_img2)

plt.savefig('Hist_eq_out1.png')
plt.show()

# %% [markdown]
# Image 2

# %%
img = cv2.imread('Allig (6).jpg')

# %%
# convert lab image 
lab_img = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)

# %%
# splitting Lab image l,a,b
l, a, b = cv2.split(lab_img)

# %%
# Apply histogram equalization 
equ = cv2.equalizeHist(l)

# %%
updated_lab_img1 = cv2.merge((equ,a,b))

# %%
hist_eq_img = cv2.cvtColor(updated_lab_img1, cv2.COLOR_LAB2BGR)

# %%
# covert RGB 
hist_eq_img = cv2.cvtColor(updated_lab_img1, cv2.COLOR_LAB2BGR)

# %%
# Apply L clache
clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
clahe_img = clahe.apply(l)

# %%
# combine the CLAHE 
updated_lab_img2 = cv2.merge((clahe_img, a, b))

# %%
CLAHE_img = cv2.cvtColor(updated_lab_img2, cv2.COLOR_LAB2BGR)

# %%
plt.figure(figsize=(12,10))
plt.subplot(3,3,1)
plt.title('Original Image')
plt.imshow(img)

plt.subplot(3,3,2)
plt.title('Hist_eq_image')
plt.imshow(hist_eq_img)

plt.subplot(3,3,3)
plt.title('CLAHE_image')
plt.imshow(CLAHE_img)

plt.subplot(3,3,4)
plt.title('Histogram equ')
plt.hist(equ.flat, bins=100, range=(0,255))

plt.subplot(3,3,5)
plt.title('updated_lab_img2')
plt.imshow(updated_lab_img1)

plt.subplot(3,3,6)
plt.title('updated_lab_img2')
plt.imshow(updated_lab_img2)

plt.savefig('Hist_eq_out2.png')
plt.show()
